# %%
import pandas as pd

# %%
prefix = "data/original_datasets/"

raw_MB = pd.read_csv(prefix + "dataset_Metabody.csv")
raw_ME = pd.read_csv(prefix + "dataset_MetaEducation.csv")
raw_MI = pd.read_csv(prefix + "dataset_MetaImagery.csv")
raw_MM = pd.read_csv(prefix + "dataset_MoveMe.csv")

# %%
# Processing MB dataset:

#print("Info raw_MB:\n", raw_MB.info(), "\n")

df_dict = {"MB" : raw_MB , "ME" : raw_ME, "MI" : raw_MI, "MM" : raw_MM}

for name, df in df_dict.items():

  bambini_2013 = list()
  canal_2022 = list()
  bambini_2024 = list()
  lago_2024 = list()

  for idx, row in df.iterrows():

    if row["Bambini et al. (2013)"] == "Y":
      bambini_2013.append(row)
      continue

    if row["Canal et al. (2022)"] == "Y":
      canal_2022.append(row)
      continue

    if  row["Bambini et al. (2024)"] == "Y":
      bambini_2024.append(row)
      continue

    if row["Lago et al. (2024)"] == "Y":
      lago_2024.append(row)
      continue


  print(name + ": \n",
    "bambini_2013: ", len(bambini_2013), "\n",
    "canal_2022: ", len(canal_2022), "\n",
    "bambini_2024: ", len(bambini_2024), "\n",
    "lago_2024: ", len(lago_2024), "\n"
    )
# Out:
# MB:
#  bambini_2013:  5
#  canal_2022:  0
#  bambini_2024:  26
#  lago_2024:  8
#
# ME:
#  bambini_2013:  42
#  canal_2022:  1
#  bambini_2024:  4
#  lago_2024:  1
#
# MI:
#  bambini_2013:  10
#  canal_2022:  23
#  bambini_2024:  1
#  lago_2024:  6
#
# MM:
#  bambini_2013:  0
#  canal_2022:  0
#  bambini_2024:  0
#  lago_2024:  0

# %% [markdown]
# |dataset|original items|actual items (including familiarity)|actual items (excluding familiarity)|
# |---------|--|---|---|
# |MetaBody|64|59|25|
# |MetaEducation|80|38|32|
# |MetaImagery|42|18|18|
# |MetaMove|60|60|60

# %%
clean_MB = raw_MB[["Metaphor", "Met_structure", "FamMetabody_Met", "SensMetabody_Met", "BodyMetabody_Met"]]
clean_MB.columns= ["Metaphor", "Met_structure", "FAMILIARITY_human", "MEANINGFULNESS_human", "BODY_RELATEDNESS_human"]
clean_MB.to_csv("data/new_datasets/human_MB.csv", index = False)

clean_ME = raw_ME[["Metaphor", "Met_structure", "FAM(M)MetaEdu_Met", "MEA(M)MetaEdu_Met", "DIFF(M)MetaEdu_Met"]]
clean_ME.columns= ["Metaphor", "Met_structure", "FAMILIARITY_human", "MEANINGFULNESS_human", "DIFFICULTY_human"]
clean_ME.to_csv("data/new_datasets/human_ME.csv", index = False)

clean_MI= raw_MI[["Metaphor", "Met_structure", "PhysMetaIma(M)_Met", "ImaMetaIma(M)_Met"]]
clean_MI.columns= ["Metaphor", "Met_structure", "PHISICALITY_human", "IMAGEABILITY_human"]
clean_MI.to_csv("data/new_datasets/human_MI.csv", index = False)

clean_MM = raw_MM[["Metaphor", "Met_structure", "FamMoveme_Met", "SensMoveme_Met"]]
clean_MM.columns= ["Metaphor", "Met_structure", "FAMILIARITY_human", "MEANINGFULNESS_human"]
clean_MM.to_csv("data/new_datasets/human_MM.csv", index = False)

# %%
prefix = "data/human_datasets/"

human_MB = pd.read_csv(prefix + "human_MB.csv")
human_values_MB = human_MB[["FAMILIARITY_human", "MEANINGFULNESS_human", "BODY_RELATEDNESS_human"]]
human_values_MB = human_values_MB.replace(",", ".", regex=True)
human_values_MB = human_values_MB.astype(float)
print("\nHuman_MB:", human_values_MB.describe())

human_ME = pd.read_csv(prefix + "human_ME.csv")
human_values_ME = human_ME[["FAMILIARITY_human", "MEANINGFULNESS_human", "DIFFICULTY_human"]]
human_values_ME = human_values_ME.replace(",", ".", regex=True)
human_values_ME = human_values_ME.astype(float)
print("\nHuman_ME:", human_values_ME.describe())

human_MI = pd.read_csv(prefix + "human_MI.csv")
human_values_MI = human_MI[["PHISICALITY_human", "IMAGEABILITY_human"]]
human_values_MI = human_values_MI.replace(",", ".", regex=True)
human_values_MI = human_values_MI.astype(float)
print("\nHuman_MI:", human_values_MI.describe())

human_MM = pd.read_csv(prefix + "human_MM.csv")
human_values_MM = human_MM[["FAMILIARITY_human", "MEANINGFULNESS_human"]]
human_values_MM = human_values_MM.replace(",", ".", regex=True)
human_values_MM = human_values_MM.astype(float)
print("\nHuman_MM:", human_values_MM.describe())
# Out:
# Human_MB:        FAMILIARITY_human  MEANINGFULNESS_human  BODY_RELATEDNESS_human
# count          54.000000             64.000000               64.000000
# mean            4.062797              4.908003                4.019181
# std             1.231482              0.940674                1.734109
# min             1.846154              2.625000                1.346154
# 25%             3.088942              4.311699                2.354167
# 50%             4.118590              5.080128                3.807692
# 75%             5.062500              5.509615                5.673077
# max             6.291667              6.384615                6.791667
#
# Human_ME:        FAMILIARITY_human  MEANINGFULNESS_human  DIFFICULTY_human
# count          80.000000             80.000000         80.000000
# mean            2.813966              3.588370          1.886662
# std             0.828771              0.598169          0.403041
# min             1.000000              2.333333          1.125000
# 25%             2.333333              3.155000          1.598974
# 50%             2.867446              3.666667          1.833333
# 75%             3.333333              4.033929          2.166667
# max             4.214668              4.708333          3.142857
#
# Human_MI:        PHISICALITY_human  IMAGEABILITY_human
# count          42.000000           42.000000
# mean            3.275627            4.277221
# std             1.651698            1.030293
# min             1.263158            2.222222
# 25%             1.912500            3.616228
# 50%             2.973684            4.083333
# 75%             4.236842            4.879386
# max             6.700000            6.500000
#
# Human_MM:        FAMILIARITY_human  MEANINGFULNESS_human
# count          60.000000             60.000000
# mean            4.643889              5.417241
# std             0.942199              0.754083
# min             2.600000              3.689655
# 25%             4.116667              4.958333
# 50%             4.666667              5.566667
# 75%             5.316667              6.076724
# max             6.566667              6.533333

# %%
results = pd.read_csv("spearman_results.csv")
results_single_run = results[["dataset","dimension","n_annot1","spearman_r_annot1","pval_annot1"]]
results_mean = results[["dataset","dimension","n_mean","spearman_r_mean","pval_mean"]]
results
# Out:
#   dataset         dimension               human_col  \
# 0      MB       FAMILIARITY       FAMILIARITY_human
# 1      MB    MEANINGFULNESS    MEANINGFULNESS_human
# 2      MB  BODY_RELATEDNESS  BODY_RELATEDNESS_human
# 3      ME       FAMILIARITY       FAMILIARITY_human
# 4      ME    MEANINGFULNESS    MEANINGFULNESS_human
# 5      ME        DIFFICULTY        DIFFICULTY_human
# 6      MI       PHISICALITY       PHISICALITY_human
# 7      MI      IMAGEABILITY      IMAGEABILITY_human
# 8      MM       FAMILIARITY       FAMILIARITY_human
# 9      MM    MEANINGFULNESS    MEANINGFULNESS_human
#
#                     synth_col  n_annot1  spearman_r_annot1   pval_annot1  \
# 0       FAMILIARITY_synthetic        23           0.082648  7.077302e-01
# 1    MEANINGFULNESS_synthetic        59           0.127033  3.376727e-01
# 2  BODY_RELATEDNESS_synthetic        64           0.783146  2.060539e-14
# 3       FAMILIARITY_synthetic        32           0.092672  6.139352e-01
# 4    MEANINGFULNESS_synthetic        38           0.032401  8.468696e-01
# 5        DIFFICULTY_synthetic        34           0.097044  5.850777e-01
# 6       PHISICALITY_synthetic        15           0.490543  6.337623e-02
# 7      IMAGEABILITY_synthetic        40           0.149291  3.578730e-01
# 8       FAMILIARITY_synthetic        60          -0.017311  8.955565e-01
# 9    MEANINGFULNESS_synthetic        60           0.009834  9.405550e-01
#
#    n_mean  spearman_r_mean     pval_mean
# 0      23         0.173440  4.286949e-01
# 1      59         0.135941  3.046002e-01
# 2      64         0.784461  1.742921e-14
# 3      32         0.185297  3.099527e-01
# 4      38         0.098748  5.553030e-01
# 5      34         0.121673  4.930362e-01
# 6      15         0.704831  3.342169e-03
# 7      40         0.290362  6.913151e-02
# 8      60         0.042675  7.461250e-01
# 9      60        -0.032360  8.061073e-01

# %%
results_single_run_sorted = results_single_run.sort_values(by= "spearman_r_annot1", ascending=False)
results_single_run_sorted
# Out:
#   dataset         dimension  n_annot1  spearman_r_annot1   pval_annot1
# 2      MB  BODY_RELATEDNESS        64           0.783146  2.060539e-14
# 6      MI       PHISICALITY        15           0.490543  6.337623e-02
# 7      MI      IMAGEABILITY        40           0.149291  3.578730e-01
# 1      MB    MEANINGFULNESS        59           0.127033  3.376727e-01
# 5      ME        DIFFICULTY        34           0.097044  5.850777e-01
# 3      ME       FAMILIARITY        32           0.092672  6.139352e-01
# 0      MB       FAMILIARITY        23           0.082648  7.077302e-01
# 4      ME    MEANINGFULNESS        38           0.032401  8.468696e-01
# 9      MM    MEANINGFULNESS        60           0.009834  9.405550e-01
# 8      MM       FAMILIARITY        60          -0.017311  8.955565e-01

# %%
results_mean_sorted = results_mean.sort_values(by= "spearman_r_mean", ascending=False)
results_mean_sorted
# Out:
#   dataset         dimension  n_mean  spearman_r_mean     pval_mean
# 2      MB  BODY_RELATEDNESS      64         0.784461  1.742921e-14
# 6      MI       PHISICALITY      15         0.704831  3.342169e-03
# 7      MI      IMAGEABILITY      40         0.290362  6.913151e-02
# 3      ME       FAMILIARITY      32         0.185297  3.099527e-01
# 0      MB       FAMILIARITY      23         0.173440  4.286949e-01
# 1      MB    MEANINGFULNESS      59         0.135941  3.046002e-01
# 5      ME        DIFFICULTY      34         0.121673  4.930362e-01
# 4      ME    MEANINGFULNESS      38         0.098748  5.553030e-01
# 8      MM       FAMILIARITY      60         0.042675  7.461250e-01
# 9      MM    MEANINGFULNESS      60        -0.032360  8.061073e-01

# %%
# Drop della colonna met_structure dai dataset sintetici

prefix = "data/synthetic_datasets/"
model = "_meta-llama-Llama-3.1-8B-Instruct_"

for name in ["MB", "ME", "MI", "MM"]:
    df = pd.read_csv(prefix + "human_" + name + ".csv")
    df.drop(columns=["Met_structure"], inplace=True)
    df.rename(columns={'Metaphor': 'metaphor'}, inplace=True)
    df.to_csv(prefix + "human_" + name + ".csv", index = False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 7
#       4 model = "_meta-llama-Llama-3.1-8B-Instruct_"
#       6 for name in ["MB", "ME", "MI", "MM"]:
# ----> 7     df = pd.read_csv(prefix + "human_" + name + model + ".csv")
#       8     df.drop(columns=["Metaphor"], inplace=True)
#       9     df.rename(columns={'Met_structure': 'metaphor'}, inplace=True)
#
# File c:\Users\jacop\OneDrive\Desktop\Metaphorical-ratings-LLMs-replication-study\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\jacop\OneDrive\Desktop\Metaphorical-ratings-LLMs-replication-study\.venv\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\jacop\OneDrive\Desktop\Metaphorical-ratings-LLMs-replication-study\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\jacop\OneDrive\Desktop\Metaphorical-ratings-LLMs-replication-study\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\jacop\OneDrive\Desktop\Metaphorical-ratings-LLMs-replication-study\.venv\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/synthetic_datasets/human_MB_meta-llama-Llama-3.1-8B-Instruct_.csv'
